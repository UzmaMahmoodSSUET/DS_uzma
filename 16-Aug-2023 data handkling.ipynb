# %%
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv("car_data.csv")

# %%
car_data.shape
# Out:
# (892, 6)

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# # Missing Values

# %%
car_data.isna()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
car_data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
car_data.isnull()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
car_data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
car_data.notna().sum()
# Out:
# name          892
# company       892
# year          892
# Price         892
# kms_driven    840
# fuel_type     837
# dtype: int64

# %%
car_data.notnull().sum()
# Out:
# name          892
# company       892
# year          892
# Price         892
# kms_driven    840
# fuel_type     837
# dtype: int64

# %%
car = pd.read_csv("car_data.csv")

# %%
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car_data.isna()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
car.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
# dropped missing value record
car.dropna(inplace=True)

# %%
car
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %% [markdown]
# # Duplicate_record

# %%
car.duplicated().sum()
# Out:
# 92

# %%
car.drop_duplicates(inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    object
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 40.7+ KB

# %%
car.name
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 2                  Maruti Suzuki Alto 800 Vxi
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
#                         ...
# 883                Maruti Suzuki Ritz VXI ABS
# 885                 Tata Indica V2 DLE BS III
# 886                      Toyota Corolla Altis
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# Name: name, Length: 745, dtype: object

# %%
car.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
car.name.str.split().str[:3]
# Out:
# 0         [Hyundai, Santro, Xing]
# 1         [Mahindra, Jeep, CL550]
# 2          [Maruti, Suzuki, Alto]
# 3           [Hyundai, Grand, i10]
# 4      [Ford, EcoSport, Titanium]
#                   ...
# 883        [Maruti, Suzuki, Ritz]
# 885            [Tata, Indica, V2]
# 886      [Toyota, Corolla, Altis]
# 888              [Tata, Zest, XM]
# 889        [Mahindra, Quanto, C8]
# Name: name, Length: 745, dtype: object

# %%
car.name = car.name.str.split().str[:3].str.join(' ')

# %%
car.name.sample(10)
# Out:
# 712             Honda WR V
# 124        Chevrolet Spark
# 19      Maruti Suzuki Alto
# 198      Toyota Innova 2.5
# 483    Toyota Fortuner 3.0
# 717    Maruti Suzuki Wagon
# 485    Tata Tigor Revotron
# 546     Hyundai Getz Prime
# 549      Chevrolet Beat PS
# 208     Maruti Suzuki Alto
# Name: name, dtype: object

# %%
car.sample(10)
# Out:
#                         name     company  year      Price  kms_driven  \
# 39        Renault Duster 110     Renault  2012   5,01,000  38,000 kms
# 460     Maruti Suzuki Baleno      Maruti  2016   5,00,000  28,000 kms
# 694  Mitsubishi Pajero Sport  Mitsubishi  2015  17,25,000  37,000 kms
# 87         Hyundai i20 Magna     Hyundai  2009   1,95,000  32,000 kms
# 467  Mitsubishi Pajero Sport  Mitsubishi  2015  15,40,000  43,222 kms
# 618      Maruti Suzuki Swift      Maruti  2014   3,15,000  44,000 kms
# 794            Hyundai Eon D     Hyundai  2013   1,70,000  20,000 kms
# 156       Maruti Suzuki Alto      Maruti  2018   3,10,000   3,000 kms
# 876      Maruti Suzuki Dzire      Maruti  2016   4,50,000   2,500 kms
# 726      Maruti Suzuki Swift      Maruti  2009   2,50,000  51,000 kms
#
#     fuel_type
# 39     Diesel
# 460    Petrol
# 694    Diesel
# 87     Petrol
# 467    Petrol
# 618    Petrol
# 794    Petrol
# 156    Petrol
# 876    Diesel
# 726    Diesel

# %%
car.company.unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
car.year
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 883    2011
# 885    2009
# 886    2009
# 888    2018
# 889    2013
# Name: year, Length: 745, dtype: object

# %%
car.year.unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
car.year =pd.to_datetime(car.year)

# %%
car.year
# Out:
# 0     2007-01-01
# 1     2006-01-01
# 2     2018-01-01
# 3     2014-01-01
# 4     2014-01-01
#          ...
# 883   2011-01-01
# 885   2009-01-01
# 886   2009-01-01
# 888   2018-01-01
# 889   2013-01-01
# Name: year, Length: 745, dtype: datetime64[ns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    datetime64[ns]
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 40.7+ KB

# %%
car
# Out:
#                        name   company       year          Price    kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01         80,000    45,000 kms
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01       4,25,000        40 kms
# 2        Maruti Suzuki Alto    Maruti 2018-01-01  Ask For Price    22,000 kms
# 3         Hyundai Grand i10   Hyundai 2014-01-01       3,25,000    28,000 kms
# 4    Ford EcoSport Titanium      Ford 2014-01-01       5,75,000    36,000 kms
# ..                      ...       ...        ...            ...           ...
# 883      Maruti Suzuki Ritz    Maruti 2011-01-01       2,70,000    50,000 kms
# 885          Tata Indica V2      Tata 2009-01-01       1,10,000    30,000 kms
# 886    Toyota Corolla Altis    Toyota 2009-01-01       3,00,000  1,32,000 kms
# 888            Tata Zest XM      Tata 2018-01-01       2,60,000    27,000 kms
# 889      Mahindra Quanto C8  Mahindra 2013-01-01       3,90,000    40,000 kms
#
#     fuel_type
# 0      Petrol
# ...

# %%
car.Price.unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car.Price.shape
# Out:
# (745,)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    datetime64[ns]
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 40.7+ KB

# %%
car.Price.isna().sum()
# Out:
# 0

# %%
car.Price.duplicated().sum()
# Out:
# 472

# %%
car.Price.value_counts()
# Out:
# Ask For Price    21
# 2,50,000         13
# 1,30,000         11
# 3,50,000         11
# 4,00,000         10
#                  ..
# 7,70,000          1
# 3,35,000          1
# 6,35,000          1
# 65,000            1
# 5,00,001          1
# Name: Price, Length: 273, dtype: int64

# %%
car = car[car.Price != "Ask For Price"]

# %%
car.Price.unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %%
car.Price.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 car.Price.astype('int32')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
car.Price.unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %%
car.Price = car.Price.str.replace( ",", '').astype('int32')
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_556\3404137957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car.Price = car.Price.str.replace( ",", '').astype('int32')

# %%
car.Price
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 724, dtype: int32

# %%
car
# Out:
#                        name   company       year   Price    kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000    45,000 kms
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40 kms
# 3         Hyundai Grand i10   Hyundai 2014-01-01  325000    28,000 kms
# 4    Ford EcoSport Titanium      Ford 2014-01-01  575000    36,000 kms
# 6                 Ford Figo      Ford 2012-01-01  175000    41,000 kms
# ..                      ...       ...        ...     ...           ...
# 883      Maruti Suzuki Ritz    Maruti 2011-01-01  270000    50,000 kms
# 885          Tata Indica V2      Tata 2009-01-01  110000    30,000 kms
# 886    Toyota Corolla Altis    Toyota 2009-01-01  300000  1,32,000 kms
# 888            Tata Zest XM      Tata 2018-01-01  260000    27,000 kms
# 889      Mahindra Quanto C8  Mahindra 2013-01-01  390000    40,000 kms
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 3      Petrol
# 4      Diesel
# 6      Diesel
# ..        ...
# ...

# %%
car.kms_driven.str.replace(",",'').str.replace("kms","").astype('float64')
# Out:
# 0       45000.0
# 1          40.0
# 3       28000.0
# 4       36000.0
# 6       41000.0
#          ...
# 883     50000.0
# 885     30000.0
# 886    132000.0
# 888     27000.0
# 889     40000.0
# Name: kms_driven, Length: 724, dtype: float64

# %%
# car.kms_driven.drop_duplicates(inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 724 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        724 non-null    object
#  1   company     724 non-null    object
#  2   year        724 non-null    datetime64[ns]
#  3   Price       724 non-null    int32
#  4   kms_driven  724 non-null    object
#  5   fuel_type   724 non-null    object
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 36.8+ KB

# %%
# Out:
# 4

# %%
car.kms_driven.unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
car.kms_driven.unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 724 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        724 non-null    object
#  1   company     724 non-null    object
#  2   year        724 non-null    datetime64[ns]
#  3   Price       724 non-null    int32
#  4   kms_driven  724 non-null    object
#  5   fuel_type   724 non-null    object
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 36.8+ KB

# %%
car
# Out:
#                        name   company       year   Price    kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000    45,000 kms
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40 kms
# 3         Hyundai Grand i10   Hyundai 2014-01-01  325000    28,000 kms
# 4    Ford EcoSport Titanium      Ford 2014-01-01  575000    36,000 kms
# 6                 Ford Figo      Ford 2012-01-01  175000    41,000 kms
# ..                      ...       ...        ...     ...           ...
# 883      Maruti Suzuki Ritz    Maruti 2011-01-01  270000    50,000 kms
# 885          Tata Indica V2      Tata 2009-01-01  110000    30,000 kms
# 886    Toyota Corolla Altis    Toyota 2009-01-01  300000  1,32,000 kms
# 888            Tata Zest XM      Tata 2018-01-01  260000    27,000 kms
# 889      Mahindra Quanto C8  Mahindra 2013-01-01  390000    40,000 kms
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 3      Petrol
# 4      Diesel
# 6      Diesel
# ..        ...
# ...

# %%
car.reset_index(drop=True, inplace=True)

# %%
car.to_csv("clean_car_data")

# %% [markdown]
# # Figuring out the data
# # expansive car
# # Cheap car

# %%
car.Price.max()
# Out:
# 8500003

# %%
car[car.Price==car.Price.max()]['name'].values[0]
# Out:
# 'Mahindra XUV500 W6'

# %%
car.Price.min()
# Out:
# 30000

# %%
car[car.Price==car.Price.min()]['name']
# Out:
# 296    Maruti Suzuki Maruti
# 692       Maruti Suzuki 800
# Name: name, dtype: object

# %%
car[car.Price==car.Price.min()]['name'].values
# Out:
# array(['Maruti Suzuki Maruti', 'Maruti Suzuki 800'], dtype=object)

# %%
# most demand brand

# %%
car.company.value_counts()
# Out:
# Maruti        202
# Hyundai       129
# Mahindra       78
# Tata           61
# Honda          51
# Toyota         34
# Chevrolet      33
# Ford           26
# Renault        26
# Volkswagen     17
# Audi           10
# Skoda          10
# BMW             8
# Datsun          6
# Nissan          6
# Mercedes        6
# Mitsubishi      5
# Mini            3
# Hindustan       3
# Fiat            3
# Force           2
# Jaguar          2
# Land            1
# Jeep            1
# Volvo           1
# Name: company, dtype: int64

# %%
car.company.value_counts().head(3)
##or
car.company.value_counts()[:3].index
# Out:
# Index(['Maruti', 'Hyundai', 'Mahindra'], dtype='object')

# %%
car.company.value_counts(ascending=True)
# or
car.company.value_counts(ascending=True)[:3]
# Out:
# Volvo    1
# Land     1
# Jeep     1
# Name: company, dtype: int64

# %%
int(car.Price.mean())
# Out:
# 403245

# %%
car.Price.max()
# Out:
# 8500003

# %%
car.Price.min()
# Out:
# 30000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(car.name, car.Price)
plt.show()

# %%
a=np.array([9,13,10,12,64,12,60])

# %%
np.sort(a)
# Out:
# array([ 9, 10, 12, 12, 13, 60, 64])

# %%
(10+12)/2
# Out:
# 11.0

# %%
np.median(a)
# Out:
# 12.0

# %%
car.Price.median()
# Out:
# 290000.0

# %%
def category(price):
    if price > car.Price.median():
        return"Expensive"
    else:
        return "Cheap"

# %%
car['category'] = car.Price.apply(category)
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_556\2396483174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['category'] = car.Price.apply(category)

# %%
car
# Out:
#                        name   company       year   Price    kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000    45,000 kms
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40 kms
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000    28,000 kms
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000    36,000 kms
# 4                 Ford Figo      Ford 2012-01-01  175000    41,000 kms
# ..                      ...       ...        ...     ...           ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000    50,000 kms
# 720          Tata Indica V2      Tata 2009-01-01  110000    30,000 kms
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000  1,32,000 kms
# 722            Tata Zest XM      Tata 2018-01-01  260000    27,000 kms
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000    40,000 kms
#
#     fuel_type   category
# 0      Petrol      Cheap
# 1      Diesel  Expensive
# 2      Petrol  Expensive
# ...

# %%
car['Categoryy_by_lambda']= car.Price.apply(lambda p: "Expensive" if p> car.Price.median() else "Cheap")
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_556\4112210319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Categoryy_by_lambda']= car.Price.apply(lambda p: "Expensive" if p> car.Price.median() else "Cheap")

# %%
car
# Out:
#                        name   company       year   Price    kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000    45,000 kms
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40 kms
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000    28,000 kms
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000    36,000 kms
# 4                 Ford Figo      Ford 2012-01-01  175000    41,000 kms
# ..                      ...       ...        ...     ...           ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000    50,000 kms
# 720          Tata Indica V2      Tata 2009-01-01  110000    30,000 kms
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000  1,32,000 kms
# 722            Tata Zest XM      Tata 2018-01-01  260000    27,000 kms
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000    40,000 kms
#
#     fuel_type   category Categoryy_by_lambda
# 0      Petrol      Cheap               Cheap
# ...

# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_excel("test_data.xlsx")

# %%
df0 = pd.read_excel('test_data.xlsx',sheet_name=0)
df1 = pd.read_excel('test_data.xlsx',sheet_name=1)
df2 = pd.read_excel('test_data.xlsx',sheet_name=2)
df3 = pd.read_excel('test_data.xlsx',sheet_name=3,header=None)

# %%
df0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df1
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# 4             55        Hussain      Hyderabad         234   Jawed
# 5             66            Ali      Hyderabad         234  Faisal
# 6             77          Sadaf         Lahore         567  Faisal
# 7             88          Kiran        Karachi         345   Najam
# 8             99            Ali        Karachi         123  Faisal
# 9              6         Kashif      Hyderabad         234  Faisal
# 10             7           Sana         Lahore         567  Faisal
# 11             8         Fatima        Karachi         345   Najam
# 12             9       Abdullah        Karachi         123  Faisal

# %%
newdf= pd.concat([df0,df1], axis=0)
newdf
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0              1           Asad        Karachi         123   Jawed
# 1              2         Sumair         Lahore         123   Jawed
# 2              3         Farjad        Karachi         145   Najam
# 3              4         Hassan         Lahore         567   Najam
# 4              5          Nasir      Hyderabad         234   Jawed
# 5              6         Kashif      Hyderabad         234  Faisal
# 6              7           Sana         Lahore         567  Faisal
# 7              8         Fatima        Karachi         345   Najam
# 8              9       Abdullah        Karachi         123  Faisal
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# ...

# %%
df3
# Out:
#    0         1          2    3       4
# 0  1      Asad    Karachi  123   Jawed
# 1  2    Sumair     Lahore  123   Jawed
# 2  3    Farjad    Karachi  145   Najam
# 3  4    Hassan     Lahore  567   Najam
# 4  5     Nasir  Hyderabad  234   Jawed
# 5  6    Kashif  Hyderabad  234  Faisal
# 6  7      Sana     Lahore  567  Faisal
# 7  8    Fatima    Karachi  345   Najam
# 8  9  Abdullah    Karachi  123  Faisal

# %%
newdf
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager     Asad  \
# 0           1.0           Asad        Karachi       123.0   Jawed      NaN
# 1           2.0         Sumair         Lahore       123.0   Jawed      NaN
# 2           3.0         Farjad        Karachi       145.0   Najam      NaN
# 3           4.0         Hassan         Lahore       567.0   Najam      NaN
# 4           5.0          Nasir      Hyderabad       234.0   Jawed      NaN
# 5           6.0         Kashif      Hyderabad       234.0  Faisal      NaN
# 6           7.0           Sana         Lahore       567.0  Faisal      NaN
# 7           8.0         Fatima        Karachi       345.0   Najam      NaN
# 8           9.0       Abdullah        Karachi       123.0  Faisal      NaN
# 0           NaN            NaN            NaN         NaN     NaN  Hussain
# 1           NaN            NaN            NaN         NaN     NaN      Ali
# ...

# %%
df0.merge(df1)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             6         Kashif      Hyderabad         234  Faisal
# 1             7           Sana         Lahore         567  Faisal
# 2             8         Fatima        Karachi         345   Najam
# 3             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1,on='sales_man_name')
# Out:
#    sales_man_id_x sales_man_name sales_man_city_x  product_id_x manager_x  \
# 0               1           Asad          Karachi           123     Jawed
# 1               6         Kashif        Hyderabad           234    Faisal
# 2               7           Sana           Lahore           567    Faisal
# 3               8         Fatima          Karachi           345     Najam
# 4               9       Abdullah          Karachi           123    Faisal
#
#    sales_man_id_y sales_man_city_y  product_id_y manager_y
# 0              44           Lahore           567     Najam
# 1               6        Hyderabad           234    Faisal
# 2               7           Lahore           567    Faisal
# 3               8          Karachi           345     Najam
# 4               9          Karachi           123    Faisal

# %%
df0.merge(df1,on='sales_man_city')
# Out:
#     sales_man_id_x sales_man_name_x sales_man_city  product_id_x manager_x  \
# 0                1             Asad        Karachi           123     Jawed
# 1                1             Asad        Karachi           123     Jawed
# 2                1             Asad        Karachi           123     Jawed
# 3                1             Asad        Karachi           123     Jawed
# 4                1             Asad        Karachi           123     Jawed
# 5                1             Asad        Karachi           123     Jawed
# 6                3           Farjad        Karachi           145     Najam
# 7                3           Farjad        Karachi           145     Najam
# 8                3           Farjad        Karachi           145     Najam
# 9                3           Farjad        Karachi           145     Najam
# 10               3           Farjad        Karachi           145     Najam
# ...

# %%
df0.columns= ['Sales_man_id', 'Sales_man_name','Sales_man_id', 'product_id', 'manager']

# %%
df0.merge(df1,left_on='Sales_man_id', right_on='sales_man_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[468], line 1
# ----> 1 df0.merge(df1,left_on='Sales_man_id', right_on='sales_man_id')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
# ...

# %%
df0
# Out:
#   Sales_man_id Sales_man_name Sales_man_id  product_id manager
# 0            1           Asad      Karachi         123   Jawed
# 1            2         Sumair       Lahore         123   Jawed
# 2            3         Farjad      Karachi         145   Najam
# 3            4         Hassan       Lahore         567   Najam
# 4            5          Nasir    Hyderabad         234   Jawed
# 5            6         Kashif    Hyderabad         234  Faisal
# 6            7           Sana       Lahore         567  Faisal
# 7            8         Fatima      Karachi         345   Najam
# 8            9       Abdullah      Karachi         123  Faisal

# %% [markdown]
# #

# %%
df1
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# 4             55        Hussain      Hyderabad         234   Jawed
# 5             66            Ali      Hyderabad         234  Faisal
# 6             77          Sadaf         Lahore         567  Faisal
# 7             88          Kiran        Karachi         345   Najam
# 8             99            Ali        Karachi         123  Faisal
# 9              6         Kashif      Hyderabad         234  Faisal
# 10             7           Sana         Lahore         567  Faisal
# 11             8         Fatima        Karachi         345   Najam
# 12             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1, left_on='Sales_man_name', right_on ='sales_man_name')
# Out:
#   Sales_man_id Sales_man_name Sales_man_id  product manager_x  sales_man_id  \
# 0            1           Asad      Karachi      123     Jawed            44
# 1            6         Kashif    Hyderabad      234    Faisal             6
# 2            7           Sana       Lahore      567    Faisal             7
# 3            8         Fatima      Karachi      345     Najam             8
# 4            9       Abdullah      Karachi      123    Faisal             9
#
#   sales_man_name sales_man_city  product_id manager_y
# 0           Asad         Lahore         567     Najam
# 1         Kashif      Hyderabad         234    Faisal
# 2           Sana         Lahore         567    Faisal
# 3         Fatima        Karachi         345     Najam
# 4       Abdullah        Karachi         123    Faisal

# %%
df0.Sales_man_name= df0.Sales_man_name.apply(lambda name: name.strip())

# %%
df0.Sales_man_name
# Out:
# 0        Asad
# 1      Sumair
# 2      Farjad
# 3      Hassan
# 4       Nasir
# 5      Kashif
# 6        Sana
# 7      Fatima
# 8    Abdullah
# Name: Sales_man_name, dtype: object

# %%
df0.merge(df1, left_on='Sales_man_id', right_on ='sales_man_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[485], line 1
# ----> 1 df0.merge(df1, left_on='Sales_man_id', right_on ='sales_man_id')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
# ...
